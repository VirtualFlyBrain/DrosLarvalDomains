# %%
import pandas as pd
import re
from ontobio import OntologyFactory

neuropils_df = pd.read_csv("./IndexKey.tsv", sep="\t")

# Superior Inferior Protocerebrum
# >
# Superior Inferior Protocerebrum on L3 CNS template - Wood2018
#
# Thoracic Segment 1 centrolateral Right
# >
# T1 right centrolateral neuropil on L3 CNS template - Wood2018
# 
# Everything with left/right gets neuropil
# Abdominal Segment 1 -> A1, Thoracic Segment 1 -> T1
#

out_df = pd.DataFrame(columns=["Label", "Anatomical_types", "Index", "centre_point"])

of = OntologyFactory()
fbbt = of.create("/repos/drosophila-anatomy-developmental-ontology/fbbt/releases/fbbt.json")
po_lsub_vnc = fbbt.descendants(node = fbbt.search('longitudinal subdivision of ventral nerve cord'), relations=['BFO_0000050'])
l = [{ 'label': fbbt.search(d), short_form: d} for d in po_lsub_vnc]
print(l)

    
for i, r in neuropils_df.iterrows():
    name = re.sub("^Abdominal Segment (\d) (.+) (Right|Left)$", r"A\1 \3 \2 neuropil", r.Name)
    name = re.sub("^Thoracic Segment (\d) (.+) (Right|Left)$", r"T\1 \3 \2 neuropil", name)
    name = re.sub("^Mandibula (.+) (Right|Left)$", r"Md\2 \1 neuropil", name)
    name = re.sub("^Maxilla (.+) (Right|Left)$", r"Mx\1 \1 neuropil", name)
    name = re.sub("^Labium (.+) (Right|Left)$", r"Lb\1 \1 neuropil", name)
    name = re.sub("(Tritocerebrum )(.+) (Right|Left)$", r"tritocerebrum \3 \2 neuropil", name)
    name = re.sub("Neuropil neuropil", "neuropil", name)
    name = re.sub("(.+)", r"\1 on L3 CNS template - Wood2018", name)
    print(name)
    neuropils_df.set_value(i, 'Name', name)
    neuropils_df.ge
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3c2b1e3b9283> in <module>()
#       3 from ontobio import OntologyFactory
#       4
# ----> 5 neuropils_df = pd.read_csv("./IndexKey.tsv", sep="\t")
#       6
#       7 # Superior Inferior Protocerebrum
#
# ...

# %%
list(neuropils_df.iterrows())[0][1]
# Out:
# Index                                                           1
# Ind_ID                                               VFB_00050002
# Class_ID                                                    FBbt_
# Name            Superior Inferior Protocerebrum on L3 CNS temp...
# Abbreviation                                                  SIP
# Note                                                          NaN
# Centre                                            [498, 129, 227]
# Colour                                                     78c679
# Name: 0, dtype: object
